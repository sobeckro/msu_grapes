# %%
pip install onnxruntime
# Out:
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.5 MB 12.0 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.5 MB 12.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.5 MB 12.2 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.5 MB 12.0 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.5 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 11.1 MB/s eta 0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [onnxruntime]
#    -------------------- ------------------- 1/2 [onnxruntime]
#    -------------------- ------------------- 1/2 [onnxruntime]
#    -------------------- ------------------- 1/2 [onnxruntime]
#    -------------------- ------------------- 1/2 [onnxruntime]
#    -------------------- ------------------- 1/2 [onnxruntime]
# ...

# %%
from ultralytics import YOLO
import cv2

# Load ONNX model instead of .pt
model = YOLO("best.onnx")

cap = cv2.VideoCapture('row3_converted-Copy1.MP4')

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

out = cv2.VideoWriter(
    "output.mp4",
    cv2.VideoWriter_fourcc(*"mp4v"),
    fps,
    (width, height)
)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading best.onnx for ONNX Runtime inference...
# requirements: Ultralytics requirement ['onnx'] not found, attempting AutoUpdate...
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/16.4 MB 11.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/16.4 MB 11.8 MB/s eta 0:00:01
#    -------------- ------------------------- 6.0/16.4 MB 9.9 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.4 MB 10.4 MB/s eta 0:00:01
#    --------------------------- ------------ 11.3/16.4 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 13.9/16.4 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 11.4 MB/s eta 0:00:00
# ...
#
# ...

# %%
from ultralytics import YOLO
import cv2

# Load ONNX model instead of .pt
model = YOLO("best.onnx")

cap2 = cv2.VideoCapture('row1_converted.MP4')

width = int(cap2.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap2.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap2.get(cv2.CAP_PROP_FPS)

out2 = cv2.VideoWriter(
    "output2.mp4",
    cv2.VideoWriter_fourcc(*"mp4v"),
    fps,
    (width, height)
)

while cap2.isOpened():
    ret, frame = cap2.read()
    if not ret:
        break

    results = model(frame)
    annotated_frame = results[0].plot()
    out2.write(annotated_frame)

cap2.release()
out2.release()
cv2.destroyAllWindows()
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading best.onnx for ONNX Runtime inference...
# Using ONNX Runtime 1.24.1 with CPUExecutionProvider
#
# 0: 640x640 17 clusters, 458.6ms
# Speed: 15.9ms preprocess, 458.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 clusters, 227.9ms
# Speed: 22.9ms preprocess, 227.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 clusters, 355.7ms
# Speed: 12.7ms preprocess, 355.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import cv2

# Load ONNX model instead of .pt
model = YOLO("best.onnx")

cap3 = cv2.VideoCapture('row2_converted.MP4')

width = int(cap3.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap3.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap3.get(cv2.CAP_PROP_FPS)

out3 = cv2.VideoWriter(
    "output3.mp4",
    cv2.VideoWriter_fourcc(*"mp4v"),
    fps,
    (width, height)
)

while cap3.isOpened():
    ret, frame = cap3.read()
    if not ret:
        break

    results = model(frame)
    annotated_frame = results[0].plot()
    out3.write(annotated_frame)

cap3.release()
out3.release()
cv2.destroyAllWindows()
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading best.onnx for ONNX Runtime inference...
# Using ONNX Runtime 1.24.1 with CPUExecutionProvider
#
# 0: 640x640 24 clusters, 61.4ms
# Speed: 5.4ms preprocess, 61.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 clusters, 63.9ms
# Speed: 5.2ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 21 clusters, 61.4ms
# Speed: 5.2ms preprocess, 61.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 19 clusters, 57.6ms
# Speed: 6.4ms preprocess, 57.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 23 clusters, 65.3ms
# Speed: 11.0ms preprocess, 65.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 clusters, 62.5ms
# ...
